# %% [markdown]
# ## Python libraries
# 1. Numpy
#     https://numpy.org/doc/stable/
#     - Quick Start Tutorial https://numpy.org/devdocs/user/quickstart.html
#     - NumPy Basic (optional) https://numpy.org/doc/1.18/numpy-user.pdf
#     - NumPy Refernce (optional) https://numpy.org/devdocs/reference/
#
#
# 2. Meshgrid
#     https://www.geeksforgeeks.org/numpy-meshgrid-function/
# 3. scikit-learn https://scikit-learn.org/stable/modules/linear_model.html

# %% [markdown]
# ## Linear Regression

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("jpmGxOB2YPo")

# %% [markdown]
# If you are finding this tutorial challenging try playing around with https://www.blog.google/topics/machine-learning/now-anyone-can-explore-machine-learning-no-coding-required/ (and make sure you watch the video as well) .

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("EvnpoUTXA0E")

# %% [markdown]
# ## Math or Statistics basics
# If you need a refresh on Linear Algebra (Optional)
# https://www.khanacademy.org/math/linear-algebra
#
# Matrix Multiplication
#  http://en.wikipedia.org/wiki/Matrix_multiplication
